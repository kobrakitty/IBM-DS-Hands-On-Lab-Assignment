# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %%
# Data Science Tools and Ecosystem

# %%
## In this notebook, Data Science Tools and Ecosystem are summarized.
#### **Objectives**:
# unordered list
# * learn about the different libraries to use for data science
# * learn about the different languages to use in data science
# * learn about open source and what that means 
# * learn the difference between different coding languages and why they are important

# %%
### Some of the popular languages that Data Scientists use are:
# *Python
# *R
# *SQL
# *Scala
# *Java
# *Julia
# *C++
# *JavaScript

# %%
### Some of the popular libraries that Data Scientists use are:
# *Numpy
# *SciPy
# *ScikitLearn
# *Pandas
# *Matplotlib
# *Seaborn

# %%
### Table of Data Science Tools
# | Data Science Tools |
# | Jupyter Notebooks |
# | R Studio |
# | Data Lab |

# %%
### Below are a few examples of evaluating arithmetic expressions in Python.
# * 2 + 3
# * 2 * 3
# * 2 / 3
print (2+3)
# Out:
# 5

# %%
### Exercise 8
# this a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
### Exercise 9
# this will convert 200 minutes to hours by diving by 60
200 / 60
# Out:
# 3.3333333333333335

# %%
### Exercise 11 - Create a markdown cell to indicate the Author's name
## Author: 
# Shelby Wentz
